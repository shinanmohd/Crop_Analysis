# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
climate=pd.read_csv(r'C:\Users\hp\Data Analyst\csv\climate_change_impact_on_agriculture_2024.csv')

# %%
climate
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %% [markdown]
# ## Description
#
# 1.
# Year: The year when the data was recorded.
# 2.
# Country: The name of the country where the data was collected.
# 3.
# Region: The geographical region where the country is located.
# 4.
# Crop_Type: The type of crop being cultivated.
# 5.
# Average_Temperature_C: The average temperature in degrees Celsius during the year.
# 6.
# Total_Precipitation_mm: The total amount of precipitation (rainfall) in millimeters over the year.
# 7.
# CO2_Emissions_MT: The amount of carbon dioxide (CO2) emissions in metric tons.
# 8.
# Crop_Yield_MT_per_HA: The crop yield in metric tons per hectare (MT/HA).
# 9.
# Extreme_Weather_Events: The number of extreme weather events recorded during the year.
# 10.
# Irrigation_Access_%: The percentage of land with access to irrigation systems.
# 11.
# Pesticide_Use_KG_per_HA: The amount of pesticide used in kilograms per hectare.
# 12.
# Fertilizer_Use_KG_per_HA: The amount of fertilizer used in kilograms per hectare.
# 13.
# Soil_Health_Index: A composite score reflecting the overall health and quality of the soil.
# 14.
# Adaptation_Strategies: Strategies adopted by the region or country to adapt to changing environmental conditions.
# 15.
# Economic_Impact_Million_USD: The economic impact of environmental factors measured in millions of US dollars.

# %%
climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %%
climate.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Region                         0
# Crop_Type                      0
# Average_Temperature_C          0
# Total_Precipitation_mm         0
# CO2_Emissions_MT               0
# Crop_Yield_MT_per_HA           0
# Extreme_Weather_Events         0
# Irrigation_Access_%            0
# Pesticide_Use_KG_per_HA        0
# Fertilizer_Use_KG_per_HA       0
# Soil_Health_Index              0
# Adaptation_Strategies          0
# Economic_Impact_Million_USD    0
# dtype: int64

# %%
climate.duplicated().sum()
# Out:
# 0

# %%
climate.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %%
climate.describe().T
# Out:
#                                count         mean         std      min  \
# Year                         10000.0  2007.088700   10.084245  1990.00
# Average_Temperature_C        10000.0    15.241299   11.466955    -4.99
# Total_Precipitation_mm       10000.0  1611.663834  805.016815   200.15
# CO2_Emissions_MT             10000.0    15.246608    8.589423     0.50
# Crop_Yield_MT_per_HA         10000.0     2.240017    0.998342     0.45
# Extreme_Weather_Events       10000.0     4.980900    3.165808     0.00
# Irrigation_Access_%          10000.0    55.248332   25.988305    10.01
# Pesticide_Use_KG_per_HA      10000.0    24.955735   14.490962     0.00
# Fertilizer_Use_KG_per_HA     10000.0    49.973708   28.711027     0.01
# Soil_Health_Index            10000.0    64.901278   20.195882    30.00
# Economic_Impact_Million_USD  10000.0   674.269658  414.591431    47.84
#
#                                    25%       50%        75%      max
# ...

# %%
climate['Country'].unique()
# Out:
# array(['India', 'China', 'France', 'Canada', 'USA', 'Argentina',
#        'Australia', 'Nigeria', 'Russia', 'Brazil'], dtype=object)

# %%
climate['Country'].nunique()
# Out:
# 10

# %%
climate['Region'].unique()
# Out:
# array(['West Bengal', 'North', 'Ile-de-France', 'Prairies', 'Tamil Nadu',
#        'Midwest', 'Northeast', 'New South Wales', 'Punjab', 'North West',
#        'South East', 'Grand Est', 'Northwestern', 'Siberian', 'Northwest',
#        'Victoria', 'Nouvelle-Aquitaine', 'South', 'Quebec', 'Southeast',
#        'Ontario', 'East', 'Pampas', 'Western Australia', 'Volga',
#        'Maharashtra', 'Provence-Alpes-Cote d’Azur', 'West', 'Central',
#        'North Central', 'Patagonia', 'Queensland', 'South West',
#        'British Columbia'], dtype=object)

# %%
climate['Region'].nunique()
# Out:
# 34

# %%
climate
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
climate['Crop_Type'].unique()
# Out:
# array(['Corn', 'Wheat', 'Coffee', 'Sugarcane', 'Fruits', 'Rice', 'Barley',
#        'Vegetables', 'Soybeans', 'Cotton'], dtype=object)

# %%
cli=climate[climate['Crop_Type']=='Rice']

# %%
cli
# Out:
#       Year    Country              Region Crop_Type  Average_Temperature_C  \
# 7     2021  Australia     New South Wales      Rice                  25.63
# 18    1997     Brazil           Northeast      Rice                  17.45
# 20    2000  Australia     New South Wales      Rice                  30.08
# 34    2004      China                East      Rice                  -0.50
# 43    2019  Argentina              Pampas      Rice                   2.33
# ...    ...        ...                 ...       ...                    ...
# 9937  2023     Canada              Quebec      Rice                  26.34
# 9940  2011  Argentina              Pampas      Rice                  -2.09
# 9949  1992  Argentina           Northeast      Rice                  17.54
# 9962  2001     France  Nouvelle-Aquitaine      Rice                  34.23
# 9990  2004      China             Central      Rice                  16.17
#
# ...

# %% [raw]
# cli

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Crop_Yield_MT_per_HA', data=cli,palette='Set1')
plt.title('CropYield by Region')
plt.xlabel('Region')
plt.ylabel('CropYield')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9244\2503558798.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Crop_Yield_MT_per_HA', data=cli,palette='Set1')

# %%
reg=cli.groupby('Country')

# %%
india=reg.get_group('India')
india
# Out:
#       Year Country       Region Crop_Type  Average_Temperature_C  \
# 149   1997   India  West Bengal      Rice                  22.27
# 196   2017   India   Tamil Nadu      Rice                  25.13
# 250   2007   India  West Bengal      Rice                   1.41
# 404   2010   India  West Bengal      Rice                  20.11
# 420   1995   India   Tamil Nadu      Rice                  22.36
# ...    ...     ...          ...       ...                    ...
# 9342  2023   India   Tamil Nadu      Rice                   0.17
# 9378  1998   India  West Bengal      Rice                  26.32
# 9498  2012   India   Tamil Nadu      Rice                   0.78
# 9626  1993   India   Tamil Nadu      Rice                  14.08
# 9930  1998   India   Tamil Nadu      Rice                  19.01
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 149                  2731.72             23.50                 1.485
# ...

# %%
china=reg.get_group('China')
china
# Out:
#       Year Country   Region Crop_Type  Average_Temperature_C  \
# 34    2004   China     East      Rice                  -0.50
# 75    2009   China     East      Rice                  21.37
# 89    2017   China    South      Rice                   1.05
# 164   2002   China     East      Rice                  11.63
# 191   1999   China  Central      Rice                  31.26
# ...    ...     ...      ...       ...                    ...
# 9679  2024   China    North      Rice                  -2.02
# 9868  2004   China  Central      Rice                  22.31
# 9894  2001   China  Central      Rice                  31.23
# 9906  1992   China    North      Rice                  29.87
# 9990  2004   China  Central      Rice                  16.17
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 34                   2892.43             18.33                 1.593
# 75                    636.48             15.22                 0.819
# ...

# %%
main=pd.concat(objs=[china,india])
main
# Out:
#       Year Country       Region Crop_Type  Average_Temperature_C  \
# 34    2004   China         East      Rice                  -0.50
# 75    2009   China         East      Rice                  21.37
# 89    2017   China        South      Rice                   1.05
# 164   2002   China         East      Rice                  11.63
# 191   1999   China      Central      Rice                  31.26
# ...    ...     ...          ...       ...                    ...
# 9342  2023   India   Tamil Nadu      Rice                   0.17
# 9378  1998   India  West Bengal      Rice                  26.32
# 9498  2012   India   Tamil Nadu      Rice                   0.78
# 9626  1993   India   Tamil Nadu      Rice                  14.08
# 9930  1998   India   Tamil Nadu      Rice                  19.01
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 34                   2892.43             18.33                 1.593
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(y="Crop_Yield_MT_per_HA",x='Region',hue='Country',data=main,palette='dark:green');

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Crop_Yield_MT_per_HA',hue='Country', data=main,color='viridis')
plt.title('Crop Yield Over Years')
plt.xlabel('Year')
plt.ylabel('Crop Yield (MT per HA)')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y='Average_Temperature_C', data=main,hue='Country',palette='colorblind')
plt.title('Average Temperature by Region')
plt.xlabel('Region')
plt.ylabel('Average Temperature (°C)')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
clinum=main.select_dtypes(include='number')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region',y='Extreme_Weather_Events',hue='Country', data=main,palette='dark:red')
plt.title('Extreme Weather Events over region')
plt.xlabel('Region')
plt.ylabel('Extreme_Weather_Events')
plt.xticks(rotation=45)
plt.show();

# %%
main['Extreme_Weather_Events'].nunique()
# Out:
# 11

# %%
cc=main[['CO2_Emissions_MT','Crop_Yield_MT_per_HA']].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cc,annot=True);

# %%
heat=main.select_dtypes(include='number')

# %%
plt.figure(figsize=((10,5)))
sns.heatmap(heat.corr(),annot=True);

# %%
main
# Out:
#       Year Country       Region Crop_Type  Average_Temperature_C  \
# 34    2004   China         East      Rice                  -0.50
# 75    2009   China         East      Rice                  21.37
# 89    2017   China        South      Rice                   1.05
# 164   2002   China         East      Rice                  11.63
# 191   1999   China      Central      Rice                  31.26
# ...    ...     ...          ...       ...                    ...
# 9342  2023   India   Tamil Nadu      Rice                   0.17
# 9378  1998   India  West Bengal      Rice                  26.32
# 9498  2012   India   Tamil Nadu      Rice                   0.78
# 9626  1993   India   Tamil Nadu      Rice                  14.08
# 9930  1998   India   Tamil Nadu      Rice                  19.01
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 34                   2892.43             18.33                 1.593
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region',y='Pesticide_Use_KG_per_HA',hue='Country', data=main,palette='dark:yellow')
plt.title('Pesticide used over regions')
plt.xlabel('Region')
plt.ylabel('Pesticide usage')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region',y='Crop_Yield_MT_per_HA',hue='Adaptation_Strategies', data=main)
plt.title('CropYield over Region')
plt.xlabel('Region')
plt.ylabel('Crop_Yield_MT_per_HA')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(y='Soil_Health_Index',x='Region', data=main)
plt.title('CropYield over Region')
plt.xlabel('Region')
plt.ylabel('Crop_Yield_MT_per_HA')
plt.xticks(rotation=45)
plt.show()
